# %%
import pandas as pd

# %%
subtest1 = pd.read_csv('D:/Users/Aravindhan.P.Dev/OneDrive - So Energy/AQ calc/Results/combination.csv')

# %%
subtest1
# Out:
#           Unnamed: 0  Unnamed: 0.1  meterPointIdentifier   eventDttm  \
# 0                  0             0              11006910  2018-03-03
# 1                  1             1              11006910  2018-03-28
# 2                  2             2              11006910  2018-04-28
# 3                  3             3              11006910  2018-05-28
# 4                  4             4              11006910  2018-06-18
# 5                  5             5              11006910  2018-06-28
# 6                  6             6              11006910  2018-03-03
# 7                  7             7              11006910  2018-03-28
# 8                  8             8              11006910  2018-04-28
# 9                  9             9              11006910  2018-05-28
# 10                10            10              11006910  2018-06-18
# 11                11            11              11006910  2018-06-28
# 12                12            12              11006910  2018-03-03
# ...
